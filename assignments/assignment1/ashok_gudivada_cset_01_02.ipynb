# %% [markdown]
# # Task 1: Baseline + Diagnostics

# %%
# %%capture
# !pip install -q import-ipynb

# %%
import import_ipynb
from ashok_gudivada_cset_01_01 import *

# %% [markdown]
# ### (a) Load the color image. If BGR, convert to RGB for display.

# %%
print_images(img_path_array)

# %% [markdown]
# ### (b) Compute a grayscale version of the image (luminance proxy).

# %%
grayscale_imgs = []  # Re-initialize as empty list
for i, img_path in enumerate(img_path_array):
    img = imread_bgr(img_path)
    wb_imgs.append(display_processing_comparison(img, show_gray, "Compute a grayscale ", i+1))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[26], line 4
#       2 for i, img_path in enumerate(img_path_array):
#       3     img = imread_bgr(img_path)
# ----> 4     wb_imgs.append(display_processing_comparison(img, show_gray, "Compute a grayscale ", i+1))
#
# File <string>:132, in display_processing_comparison(img_bgr, process_fn, process_name, img_index)
#
# File <string>:18, in bgr2rgb(img)
#
# error: OpenCV(4.7.0) /Users/xperience/GHA-OCV-Python/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
